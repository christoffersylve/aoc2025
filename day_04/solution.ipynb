# %% [markdown]
# # Part 1

# %%
input = []

with open("input.txt") as lines:
  for line in lines:
    input.append(list(line.strip()))


nbr_accessible_rolls = 0

for r, row in enumerate(input):
  for c, cols in enumerate(row):
    nrb_adjecent_rolls = 0
    temp = []
    for i in range(max(r-1,0),min(r+2,len(input))):
      # print("ranges",max(c-1,0),min(c+1,len(row)-1))
      for j in range(max(c-1,0),min(c+2,len(row))):
        if cols == 'a': 
          print("js",i,j,"Fucking ranges",max(c-1,0),min(c+2,len(row)), "Adding",input[i][j])
          # print("Row:",i,"Checking c:",cols,c+1,len(row)-1,"J:",j)
        
        temp.append(input[i][j])

    if cols == 'i': print("Letters",temp)

# abc
# def
# ghi
# Out:
# js 0 0 Fucking ranges 0 2 Adding a
# js 0 1 Fucking ranges 0 2 Adding b
# js 1 0 Fucking ranges 0 2 Adding d
# js 1 1 Fucking ranges 0 2 Adding e
# Letters ['e', 'f', 'h', 'i']

# %%
input = []

with open("input.txt") as lines:
  for line in lines:
    input.append(list(line.strip()))

nbr_accessible_rolls = 0

for r, row in enumerate(input):
  for c, col in enumerate(row):
    nbr_adjecent_rolls = -1
    temp = []
    if col == "@":
      for i in range(max(r-1,0),min(r+2,len(input))):
        for j in range(max(c-1,0),min(c+2,len(row))):
          temp.append(input[i][j])
          if input[i][j] == "@":
            nbr_adjecent_rolls += 1
      if nbr_adjecent_rolls < 4:
        nbr_accessible_rolls += 1

print("Part 1 Answer:",nbr_accessible_rolls)
# Out:
# 1495

# %% [markdown]
# # Part 2
